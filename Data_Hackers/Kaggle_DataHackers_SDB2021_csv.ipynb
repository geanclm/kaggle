# %% [markdown]
# # Data Hackers - State of Data Brazil 2021
#
# [Dataset](https://www.kaggle.com/datasets/datahackers/state-of-data-2021)
#
# [Como analisar esse dataset (por Data Hackers)]<br>
# (https://www.kaggle.com/code/datahackers/como-analisar-esse-dataset-por-data-hackers

# %%
# Analizando o Dataset no Jupyter Notebook
# by geanclm in 25/04/2022 at 09:15h

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv(r'dataset\State of Data 2021 - Dataset - Pgina1.csv', low_memory=False)

# %%
df.head(3)
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2  vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
#
#   ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                      35-39           Masculino
# 1                      35-39           Masculino
# 2                      30-34           Masculino
#
#   ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                    Ceará (CE)                          CE
# 1                    Bahia (BA)                          BA
# 2           Santa Catarina (SC)                          SC
#
#   ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 0                        Nordeste                             NaN
# 1                        Nordeste                         Sudeste
# 2                             Sul                             NaN
#
# ...

# %%
df.shape
# Out:
# (2645, 356)
